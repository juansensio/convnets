# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # LeNet5
#
# [![colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/juansensio/convnets/blob/master/models/1998_lenet5.ipynb)
#
# LeNet 5 is one of the first convolutional neural networks. It was introduced in 1998 by [Yann LeCun et al.](http://vision.stanford.edu/cs598_spring07/papers/Lecun98.pdf) and it was used to classify handwritten digits. It was the first network that was able to achieve a high accuracy on this task.
#
# ![lenet5](pics/lenet5.png)

# %%
import torch 

def block(ci, co, k=5, s=1, p=0):
    return torch.nn.Sequential(
        torch.nn.Conv2d(ci, co, k, s, p),
        torch.nn.Tanh(),
        torch.nn.AvgPool2d(2, stride=2)
    )

class LeNet5(torch.nn.Module):
  def __init__(self, n_channels=1, n_outputs=10):
    super().__init__()
    self.conv1 = block(n_channels, 6)
    self.conv2 = block(6, 16)
    self.conv3 = torch.nn.Sequential(
        torch.nn.Conv2d(16, 120, 5, padding=0),
        torch.nn.Tanh()
    )
    self.fc1 = torch.nn.Sequential(
        torch.nn.Linear(120, 84),
        torch.nn.Tanh()
    )
    self.fc2 = torch.nn.Linear(84, 10)

  def forward(self, x):
    x = self.conv1(x)
    x = self.conv2(x)
    x = self.conv3(x)
    x = x.view(x.shape[0], -1)
    x = self.fc1(x)
    x = self.fc2(x)
    return x

# %%
lenet5 = LeNet5()
output = lenet5(torch.randn(64, 1, 32, 32))
output.shape
# Out:
# torch.Size([64, 10])

# %%
import torchvision

dataloader = {
    'train': torch.utils.data.DataLoader(torchvision.datasets.MNIST('./data', train=True, download=True,
                       transform=torchvision.transforms.Compose([
                            torchvision.transforms.ToTensor(),
                            torchvision.transforms.Normalize((0.1307,), (0.3081,))
                            ])
                      ), batch_size=36, shuffle=True, pin_memory=True),
    'test': torch.utils.data.DataLoader(torchvision.datasets.MNIST('./data', train=False,
                   transform=torchvision.transforms.Compose([
                        torchvision.transforms.ToTensor(),
                        torchvision.transforms.Normalize((0.1307,), (0.3081,))
                        ])
                     ), batch_size=36, shuffle=False, pin_memory=True)
}

# %%
# plot images

import matplotlib.pyplot as plt

imgs, labels = next(iter(dataloader['train']))

rs, cs = 6, 6 
fig, axs = plt.subplots(rs, cs, figsize=(5,5))
for i, (x, y) in enumerate(zip(imgs, labels)):
	ax = axs[i//cs, i%cs]
	ax.imshow(x[0], cmap='gray')
	ax.set_title(y.item())
	ax.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# Since the model is designed to work with 32 x 32 inputs, and MNIST images are 28 x 28, we will pad the images with two pixels of zeros around the border.

# %%
model = torch.nn.Sequential(
    torch.nn.ConstantPad2d(2, 0.),
    LeNet5()
)

output = model(imgs)
output.shape
# Out:
# torch.Size([36, 10])

# %%
from fastprogress.fastprogress import master_bar, progress_bar
import numpy as np
from convnets.train import fit

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

optimizer = torch.optim.Adam(model.parameters())
criterion = torch.nn.CrossEntropyLoss()

hist = fit(model, dataloader, optimizer, criterion, device)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Epoch 1/20 loss 0.21255 error 0.06261 val_loss 0.08818 val_error 0.02671<p>Epoch 2/20 loss 0.07180 error 0.02211 val_loss 0.05950 val_error 0.01928<p>Epoch 3/20 loss 0.05126 error 0.01622 val_loss 0.06506 val_error 0.02088<p>Epoch 4/20 loss 0.04117 error 0.01295 val_loss 0.04847 val_error 0.01589<p>Epoch 5/20 loss 0.03389 error 0.01093 val_loss 0.04924 val_error 0.01599<p>Epoch 6/20 loss 0.02846 error 0.00905 val_loss 0.05194 val_error 0.01549<p>Epoch 7/20 loss 0.02412 error 0.00792 val_loss 0.04881 val_error 0.01539<p>Epoch 8/20 loss 0.02117 error 0.00722 val_loss 0.05207 val_error 0.01542<p>Epoch 9/20 loss 0.01809 error 0.00610 val_loss 0.04066 val_error 0.01319<p>Epoch 10/20 loss 0.01658 error 0.00522 val_loss 0.04883 val_error 0.01459<p>Epoch 11/20 loss 0.01541 error 0.00518 val_loss 0.05414 val_error 0.01562<p>Epoch 12/20 loss 0.01414 error 0.00463 val_loss 0.05876 val_error 0.01689<p>Epoch 13/20 loss 0.01273 error 0.00412 val_loss 0.05143 val_error 0.01512<p>Epoch 14/20 loss 0.01288 error 0.00417 val_loss 0.04957 val_error 0.01399<p>Epoch 15/20 loss 0.01151 error 0.00388 val_loss 0.04334 val_error 0.01239<p>Epoch 16/20 loss 0.01109 error 0.00370 val_loss 0.05202 val_error 0.01499<p>Epoch 17/20 loss 0.01097 error 0.00367 val_loss 0.05282 val_error 0.01339<p>Epoch 18/20 loss 0.00918 error 0.00300 val_loss 0.05550 val_error 0.01409<p>Epoch 19/20 loss 0.01107 error 0.00367 val_loss 0.05759 val_error 0.01452<p>Epoch 20/20 loss 0.00836 error 0.00298 val_loss 0.05200 val_error 0.01369

# %%
import pandas as pd 

df = pd.DataFrame(hist)
fig = plt.figure(figsize=(8,3))
ax = plt.subplot(111)
df.plot(x='epoch', y ='error', ax=ax, logy=True, xticks=df.epoch.values)
df.plot(x='epoch', y ='val_error', ax=ax, logy=True, xticks=df.epoch.values)
plt.grid(True)
plt.show()

# %% [markdown]
# Error rate on the test set reported on the original paper is around 1%, which we have been able to reproduce.
