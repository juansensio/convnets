# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # LeNet5
#
# [![colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/juansensio/convnets/blob/master/models/1998_lenet5.ipynb)
#
# LeNet 5 is one of the first convolutional neural networks. It was introduced in 1998 by [Yann LeCun et al.](http://vision.stanford.edu/cs598_spring07/papers/Lecun98.pdf) and it was used to classify handwritten digits. It was the first network that was able to achieve a high accuracy on this task.
#
# ![lenet5](pics/lenet5.png)

# %%
import torch 

def block(ci, co, k=5, s=1, p=0):
    return torch.nn.Sequential(
        torch.nn.Conv2d(ci, co, k, s, p),
        torch.nn.Tanh(),
        torch.nn.AvgPool2d(2, stride=2)
    )

class LeNet5(torch.nn.Module):
  def __init__(self, n_channels=1, n_outputs=10):
    super().__init__()
    self.conv1 = block(n_channels, 6)
    self.conv2 = block(6, 16)
    self.conv3 = torch.nn.Sequential(
        torch.nn.Conv2d(16, 120, 5, padding=0),
        torch.nn.Tanh()
    )
    self.fc1 = torch.nn.Sequential(
        torch.nn.Linear(120, 84),
        torch.nn.Tanh()
    )
    self.fc2 = torch.nn.Linear(84, 10)

  def forward(self, x):
    x = self.conv1(x)
    x = self.conv2(x)
    x = self.conv3(x)
    x = x.view(x.shape[0], -1)
    x = self.fc1(x)
    x = self.fc2(x)
    return x

# %%
lenet5 = LeNet5()
output = lenet5(torch.randn(64, 1, 32, 32))
output.shape
# Out:
# torch.Size([64, 10])

# %%
import torchvision

dataloader = {
    'train': torch.utils.data.DataLoader(torchvision.datasets.MNIST('./data', train=True, download=True,
                       transform=torchvision.transforms.Compose([
                            torchvision.transforms.ToTensor(),
                            torchvision.transforms.Normalize((0.1307,), (0.3081,))
                            ])
                      ), batch_size=36, shuffle=True, pin_memory=True),
    'test': torch.utils.data.DataLoader(torchvision.datasets.MNIST('./data', train=False,
                   transform=torchvision.transforms.Compose([
                        torchvision.transforms.ToTensor(),
                        torchvision.transforms.Normalize((0.1307,), (0.3081,))
                        ])
                     ), batch_size=36, shuffle=False, pin_memory=True)
}

# %%
# plot images

import matplotlib.pyplot as plt

imgs, labels = next(iter(dataloader['train']))

rs, cs = 6, 6 
fig, axs = plt.subplots(rs, cs, figsize=(5,5))
for i, (x, y) in enumerate(zip(imgs, labels)):
	ax = axs[i//cs, i%cs]
	ax.imshow(x[0], cmap='gray')
	ax.set_title(y.item())
	ax.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# Since the model is designed to work with 32 x 32 inputs, and MNIST images are 28 x 28, we will pad the images with two pixels of zeros around the border.

# %%
model = torch.nn.Sequential(
    torch.nn.ConstantPad2d(2, 0.),
    LeNet5()
)

output = model(imgs)
output.shape
# Out:
# torch.Size([36, 10])

# %%
from fastprogress.fastprogress import master_bar, progress_bar
import numpy as np
from convnets.train import fit

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

optimizer = torch.optim.Adam(model.parameters())
criterion = torch.nn.CrossEntropyLoss()

hist = fit(model, dataloader, optimizer, criterion, device)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Epoch 1/20 loss 0.19834 error 0.05744 val_loss 0.07400 val_error 0.02371<p>Epoch 2/20 loss 0.06539 error 0.02020 val_loss 0.04968 val_error 0.01552<p>Epoch 3/20 loss 0.04657 error 0.01430 val_loss 0.04189 val_error 0.01372<p>Epoch 4/20 loss 0.03726 error 0.01176 val_loss 0.03683 val_error 0.01149<p>Epoch 5/20 loss 0.03192 error 0.00965 val_loss 0.03475 val_error 0.01139<p>Epoch 6/20 loss 0.02583 error 0.00818 val_loss 0.03438 val_error 0.01042<p>Epoch 7/20 loss 0.02299 error 0.00715 val_loss 0.03405 val_error 0.01079<p>Epoch 8/20 loss 0.01971 error 0.00617 val_loss 0.03585 val_error 0.01079<p>Epoch 9/20 loss 0.01796 error 0.00582 val_loss 0.04591 val_error 0.01449<p>Epoch 10/20 loss 0.01556 error 0.00513 val_loss 0.03842 val_error 0.01099<p>Epoch 11/20 loss 0.01405 error 0.00447 val_loss 0.03691 val_error 0.01069<p>Epoch 12/20 loss 0.01238 error 0.00417 val_loss 0.03921 val_error 0.01099<p>Epoch 13/20 loss 0.01270 error 0.00433 val_loss 0.03026 val_error 0.00839<p>Epoch 14/20 loss 0.01115 error 0.00374 val_loss 0.03744 val_error 0.01099<p>Epoch 15/20 loss 0.01061 error 0.00357 val_loss 0.03887 val_error 0.01129<p>Epoch 16/20 loss 0.01033 error 0.00318 val_loss 0.03645 val_error 0.01099<p>Epoch 17/20 loss 0.00866 error 0.00308 val_loss 0.03431 val_error 0.01049<p>Epoch 18/20 loss 0.00830 error 0.00268 val_loss 0.03588 val_error 0.00979<p>Epoch 19/20 loss 0.00788 error 0.00262 val_loss 0.04463 val_error 0.01169<p>Epoch 20/20 loss 0.00863 error 0.00283 val_loss 0.03640 val_error 0.00989

# %%
import pandas as pd 

df = pd.DataFrame(hist)
fig = plt.figure(figsize=(8,3))
ax = plt.subplot(111)
df.plot(x='epoch', y ='error', ax=ax, logy=True, xticks=df.epoch.values)
df.plot(x='epoch', y ='val_error', ax=ax, logy=True, xticks=df.epoch.values)
plt.grid(True)
plt.show()

# %% [markdown]
# Error rate on the test set reported on the original paper is around 1%, which we have been able to reproduce.
